# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniket1313/Python_ML_Practice/blob/master/Ch06_ML_Mastery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #6.3 Summary
# 1. Histograms
# 2. Density plots
# 3. Correlation Matrix
# 4. Scatter plot Matrix

# %%
#Univariate Histogram

import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("pima-indians-diabetes.csv")
data
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
data.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
data.shape
# Out:
# (767, 9)

# %%
filename = 'pima-indians-diabetes.csv'
names = ['preg','plans','skin','test','mass','pedi','age','class']
df = pd.read_csv(filename,names=names)

# %%
df.head()
# Out:
#    preg  plans  skin  test  mass   pedi  age  class
# 6   148     72    35     0  33.6  0.627   50      1
# 1    85     66    29     0  26.6  0.351   31      0
# 8   183     64     0     0  23.3  0.672   32      1
# 1    89     66    23    94  28.1  0.167   21      0
# 0   137     40    35   168  43.1  2.288   33      1

# %%
#6.1 Histogram

df.hist()
plt.show()

# %%
#6.1.2 Density plot :Gives distribution of each attribute
plt.figure(figsize=(30,15))
df.plot(kind='density',subplots=True,layout=(3,3,),sharex=False)
plt.show()
#We can see that distribution for each attribute is clearer than the histogram

# %%
#6.1.3 Box snd Whisker plots
#Box and Whisker plots 
#Whiskers give idea of spread of data and dots

df.plot(kind='box', subplots = True ,layout=(3,3),sharex = False ,sharey = False)
plt.figure(figsize=(10,15))
plt.show()

# %%
#6.2.1 Correlation Matrix Plot

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
correlations = df.corr()

#plot correlation matrix 

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations,vmin =-1,vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %%
#We can see symmetrical matrix.Bottom left is like top right.

#Scatter Plot Matrix :

pd.plotting.scatter_matrix(df, alpha=0.2)
plt.show()
